# %%
import pandas as pd

# %%
pd.read_excel('TrainInfo.xlsx')
# Out:
#      S.No  Train_No                               Train_Name  \
# 0       1     15609                      Abadh Assam Express
# 1       2     58719              Abhanpur Rajim NG Passenger
# 2       3     58721              Abhanpur Rajim NG Passenger
# 3       4     14722                   Abohar Jodhpur Express
# 4       5     54703                 Abohar Jodhpur Passenger
# ..    ...       ...                                      ...
# 495   496      8758           Ambikapur Anuppur MEMU Special
# 496   497      8242          Ambikapur Durg Covid 19 Special
# 497   498     18242     Ambikapur Durg Express Cum Passenger
# 498   499     11266  Ambikapur Madan Mahal Intercity Express
# 499   500      1266  Ambikapur Madan Mahal Intercity Special
#
#                   From                 To
# 0             Guwahati   Lalgarh Junction
# 1    Abhanpur Junction              Rajim
# 2    Abhanpur Junction              Rajim
# 3      Abohar Junction   Jodhpur Junction
# ...

# %%
read = pd.read_excel('TrainInfo.xlsx')
for i in read:
    print(i)
# Out:
# S.No
# Train_No
# Train_Name
# From
# To

# %%
myTrain = []

# %%
print(myTrain)
print(len(MyTrain))
# Out:
# [                                       Train_Name               From  \
# Train_No
# 15609                         Abadh Assam Express           Guwahati
# 58719                 Abhanpur Rajim NG Passenger  Abhanpur Junction
# 58721                 Abhanpur Rajim NG Passenger  Abhanpur Junction
# 14722                      Abohar Jodhpur Express    Abohar Junction
# 54703                    Abohar Jodhpur Passenger    Abohar Junction
# ...                                           ...                ...
# 8758               Ambikapur Anuppur MEMU Special          Ambikapur
# 8242              Ambikapur Durg Covid 19 Special          Ambikapur
# 18242        Ambikapur Durg Express Cum Passenger          Ambikapur
# 11266     Ambikapur Madan Mahal Intercity Express          Ambikapur
# 1266      Ambikapur Madan Mahal Intercity Special          Ambikapur
#
#                          To
# Train_No
# 15609      Lalgarh Junction
# 58719                 Rajim
# 58721                 Rajim
# ...

# %%
read = pd.read_excel('TrainInfo.xlsx')
# Out:
#       S.No  Train_No                                    Train_Name  \
# 0        1     15609                           Abadh Assam Express
# 1        2     58719                   Abhanpur Rajim NG Passenger
# 2        3     58721                   Abhanpur Rajim NG Passenger
# 3        4     14722                        Abohar Jodhpur Express
# 4        5     54703                      Abohar Jodhpur Passenger
# ...    ...       ...                                           ...
# 2543  2544     19722                                BXN-JP Express
# 2544  2545     56666  Byndoor Mookambika Road - Kasargod Passenger
# 2545  2546      7895                                       Bza-MTM
# 2546  2547      7898                                       Bza-MTM
# 2547  2548     77261                             Bza-MTM Passenger
#
#                          From                To
# 0                    Guwahati  Lalgarh Junction
# 1           Abhanpur Junction             Rajim
# ...

# %%
read = pd.read_excel('TrainInfo.xlsx')
print(read[0][1])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# ...
